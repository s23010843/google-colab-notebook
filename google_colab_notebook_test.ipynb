# %% [markdown]
# <a href="https://colab.research.google.com/github/s23010843/google-colab-notebook/blob/main/google_colab_notebook_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # R Markdown

# %% [markdown]
# # Normal Markdown

# %% [markdown]
# # R Markdown Starting

# %%
"Hello World"#print("Hello R")
# Out:
# [1] "Hello World"

# %%
"Connect with GitHub"
# Out:
# [1] "Connect with GitHub"
